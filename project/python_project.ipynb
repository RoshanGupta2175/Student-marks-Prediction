# %%
import pandas as pd

df = pd.read_csv("student_marks_dataset.csv")
df.head()
# Out:
#    study_hours  sleep_hours  attendance  previous_score  final_score
# 0            2            4          97              57           62
# 1            4            5          97              46           79
# 2            2            8          77              42           52
# 3            2            5          64              72           77
# 4            1            8          62              85           85

# %%
df.tail()
# Out:
#      study_hours  sleep_hours  attendance  previous_score  final_score
# 115            8            7          78              83          100
# 116            9            7         100              90          100
# 117            2            6          82              82           89
# 118           10            6          55              92          100
# 119            5            5          62              49           61

# %%
df.describe()
# Out:
#        study_hours  sleep_hours  attendance  previous_score  final_score
# count   120.000000    120.00000  120.000000      120.000000    120.00000
# mean      5.525000      6.12500   75.133333       69.733333     86.00000
# std       2.777347      1.64272   14.261032       16.118121     12.74112
# min       1.000000      4.00000   50.000000       41.000000     52.00000
# 25%       3.000000      5.00000   63.000000       56.000000     77.75000
# 50%       6.000000      6.00000   75.000000       72.000000     88.50000
# 75%       8.000000      8.00000   88.000000       82.250000     98.50000
# max      10.000000      9.00000  100.000000       94.000000    100.00000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot = True, cmap="Blues")
plt.title("correlation heatmap")
plt.show()

# %%
sns.scatterplot(x="study_hours", y="final_score" , data=df)
plt.show
plt.grid()

# %%
sns.scatterplot(x ="previous_score" , y = "final_score", data=df)
plt.grid()
plt.show()

# %%
sns.histplot(df["final_score"], bins=10 , kde= True)
plt.show()

# %%
x = df.drop("final_score", axis=1)
y =df["final_score"]
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("R2 Score:", r2)
# Out:
# MAE: 5.131166875998205
# R2 Score: 0.7933411593789119

# %%
new_student = [[6, 7, 85, 70]]   # study, sleep, attendance, previous
prediction = model.predict(new_student)

print("Predicted Final Score:", prediction[0])
# Out:
# Predicted Final Score: 90.69185627472473
# D:\ana\envs\roshan\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
